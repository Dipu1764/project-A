# %% [markdown]
# <a href="https://colab.research.google.com/github/Dipu1764/project-A/blob/main/hotal_booking_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Business Problem**
#
# In recent years, City Hotel and Resort Hotel have seen high cancellation rates. Each hotel is now dealing with a number of issues as a result, including fewer revenues and less than ideal hotel room use. Consequently, lowering cancellation rates is both hotels' primary goal in order to increase their efficiency in generating revenue, and for us to offer thorough business advice to address this problem.
#
# The analysis of hotel booking cancellations as well as other factors that have no bearing on their business and yearly revenue generation are the main topics of this report

# %% [markdown]
# # **Importing** **libaraies**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **loading the dataset**

# %%
data = pd.read_csv('/content/Hotel Bookings.csv')
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0     2.0  ...    No Deposit
# ...

# %% [markdown]
# # **Exploratry data analysis and data cleaning**

# %%
data.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0     2.0  ...    No Deposit
# ...

# %%
data.tail()
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 14679  Resort Hotel            0          0               2017
# 14680  Resort Hotel            1        399               2015
# 14681  Resort Hotel            1        202               2015
# 14682  Resort Hotel            1        259               2015
# 14683  Resort Hotel            1        259               2015
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 14679              April                        16                         18
# 14680           December                        52                         22
# 14681               July                        30                         22
# 14682          September                        38                         17
# 14683          September                        38                         17
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %%
data.shape
# Out:
# (14684, 32)

# %%
data.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14684 entries, 0 to 14683
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           14684 non-null  object
#  1   is_canceled                     14684 non-null  int64
#  2   lead_time                       14684 non-null  int64
#  3   arrival_date_year               14684 non-null  int64
#  4   arrival_date_month              14684 non-null  object
#  5   arrival_date_week_number        14684 non-null  int64
#  6   arrival_date_day_of_month       14684 non-null  int64
#  7   stays_in_weekend_nights         14684 non-null  int64
#  8   stays_in_week_nights            14684 non-null  int64
#  9   adults                          14683 non-null  float64
#  10  children                        14683 non-null  float64
#  11  babies                          14683 non-null  float64
# ...

# %%
data['reservation_status_date'] = pd.to_datetime(data['reservation_status_date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14684 entries, 0 to 14683
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           14684 non-null  object
#  1   is_canceled                     14684 non-null  int64
#  2   lead_time                       14684 non-null  int64
#  3   arrival_date_year               14684 non-null  int64
#  4   arrival_date_month              14684 non-null  object
#  5   arrival_date_week_number        14684 non-null  int64
#  6   arrival_date_day_of_month       14684 non-null  int64
#  7   stays_in_weekend_nights         14684 non-null  int64
#  8   stays_in_week_nights            14684 non-null  int64
#  9   adults                          14683 non-null  float64
#  10  children                        14683 non-null  float64
#  11  babies                          14683 non-null  float64
# ...

# %%
data.describe(include='object')
# Out:
#                hotel arrival_date_month   meal country market_segment  \
# count          14684              14684  14683   14246          14683
# unique             1                 12      5      86              6
# top     Resort Hotel               July     BB     PRT      Online TA
# freq           14684               2087  10577    8220           7387
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                 14683              14683              14683
# unique                    4                  9                 11
# top                   TA/TO                  A                  A
# freq                  11212               8605               7176
#
#        deposit_type customer_type reservation_status
# count         14683         14683              14683
# unique            3             4                  3
# top      No Deposit     Transient           Canceled
# freq          13295         11630               9913

# %%
for col in data.describe(include='object').columns:
  print(col)
  print(data[col].unique())
  print('-'*50)
# Out:
# hotel
# ['Resort Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined' nan]
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR']
# --------------------------------------------------
# market_segment
# ...

# %%
data.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                1
# children                              1
# babies                                1
# meal                                  1
# country                             438
# market_segment                        1
# distribution_channel                  1
# is_repeated_guest                     1
# previous_cancellations                1
# previous_bookings_not_canceled        1
# reserved_room_type                    1
# assigned_room_type                    1
# booking_changes                       1
# deposit_type                          1
# ...

# %%
data.drop(['company','agent'],axis=1,inplace=True)
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
data.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  14246.000000  14246.000000       14246.000000
# mean       0.711779    120.006177        2016.025832
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     37.000000        2015.000000
# 50%        1.000000     96.000000        2016.000000
# 75%        1.000000    182.000000        2017.000000
# max        1.000000    737.000000        2017.000000
# std        0.452951    100.540686           0.749517
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              14246.000000               14246.000000
# mean                  28.506739                  15.864874
# min                    1.000000                   1.000000
# 25%                   18.000000                   8.000000
# 50%                   29.000000                  16.000000
# 75%                   38.000000                  24.000000
# max                   53.000000                  31.000000
# ...

# %%
data = data[data['adr']<5000]

# %% [markdown]
# # **Data analysis and visualization**

# %%
cancelled_perc = data['is_canceled'].value_counts(normalize=True)
print=(cancelled_perc)

plt.figure(figsize=(5,4))
plt.title('Reservation status count')
plt.bar(['Not canceled','Canceled'],data['is_canceled'].value_counts(),edgecolor = 'k', width=0.7)
plt.show()

# %%
plt.figure(figsize=(8,4))
ax1 = sns.countplot(x='hotel',hue='is_canceled',data=data, palette='Blues')
legend_labels,_ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1,1))
plt.title('Reservation status in different hotels', size = 20)
plt.xlabel('Hotel')
plt.ylabel('Number of reservations')
plt.show()

# %%
resort_hotel = data[data['hotel']=='Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# is_canceled
# 1    0.711779
# 0    0.288221
# Name: proportion, dtype: float64

# %%
city_hotel = data[data['hotel']=='city Hotel']
city_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# Series([], Name: proportion, dtype: float64)

# %%
resort_hotal = resort_hotel.groupby('reservation_status_date')['adr'].mean()
city_hotal = city_hotel.groupby('reservation_status_date')['adr'].mean()

# %%
plt.figure(figsize=(16,8))
plt.title('Average Daily Rate in City and Resort Hotel',fontsize=30)
plt.plot(resort_hotal.index,resort_hotal,label='Resort Hotel')
plt.plot(city_hotal.index,city_hotal,label='City Hotel')
plt.legend(fontsize=30)
plt.show()

# %%
data['month'] = data['reservation_status_date'].dt.month
plt.figure(figsize=(10,8))
ax1 = sns.countplot(x='month', hue = 'is_canceled', data=data, palette='bright')
legend_labels,_ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1,1))
plt.title('Reservation status in each month', size = 20)
plt.xlabel('Month')
plt.ylabel('Number of reservations')
plt.legend(['Not canceled','Canceled'])
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.title('ADR per months', fontsize = 20)
plt.xlabel('Month')
plt.ylabel('ADR')
sns.boxplot(x='month', y='adr', data=data[data['is_canceled'] == 1].groupby('month')[['adr']].sum().reset_index())
plt.show()

# %%
cancelled_data = data[data['is_canceled'] == 1]
top_10_country = cancelled_data['country'].value_counts()[:10]
plt.figure(figsize=(10,6))
plt.title('Top 10 countries with most canceled reservations')
plt.pie(top_10_country, labels = top_10_country.index, autopct='%.2f')
plt.show()

# %%
data['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        7314
# Groups           2903
# Offline TA/TO    1907
# Direct           1425
# Corporate         654
# Complementary      43
# Name: count, dtype: int64

# %%
data['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.513407
# Groups           0.203776
# Offline TA/TO    0.133862
# Direct           0.100028
# Corporate        0.045908
# Complementary    0.003018
# Name: proportion, dtype: float64

# %%
cancelled_data['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.599408
# Groups           0.199606
# Offline TA/TO    0.088166
# Direct           0.079980
# Corporate        0.029684
# Complementary    0.003156
# Name: proportion, dtype: float64

# %%
cancelled_data = data[data['is_canceled'] == 1]
cancelled_df_adr = cancelled_data.groupby('reservation_status_date')['adr'].mean().reset_index()
cancelled_df_adr.sort_values('reservation_status_date', inplace=True)


not_cancelled_data = data[data['is_canceled'] == 0]
not_cancelled_df_adr = not_cancelled_data.groupby('reservation_status_date')['adr'].mean().reset_index()
not_cancelled_df_adr.sort_values('reservation_status_date', inplace=True)


plt.figure(figsize=(15,8))
plt.title('Average Daily Rate')
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label='Not canceled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label='Canceled')
plt.legend()
plt.xlabel('Reservation Status Date')
plt.ylabel('Average Daily Rate (ADR)')
plt.show()

# %%
cancelled_df_adr = cancelled_df_adr[(cancelled_df_adr['reservation_status_date']>'2016')&(cancelled_df_adr['reservation_status_date']>'2016')]
not_cancelled_df_adr = not_cancelled_df_adr[(not_cancelled_df_adr['reservation_status_date']>'2016')&(not_cancelled_df_adr['reservation_status_date']>'2016')]

# %%
plt.figure(figsize=(20,6))
plt.title('Average Daily Rate')
plt.plot(not_cancelled_df_adr['reservation_status_date'], not_cancelled_df_adr['adr'], label='Not canceled')
plt.plot(cancelled_df_adr['reservation_status_date'], cancelled_df_adr['adr'], label='Canceled')
plt.legend()
plt.xlabel('Reservation Status Date')
plt.ylabel('Average Daily Rate (ADR)')
plt.show()

# %% [markdown]
# # **Suggestions**
#
# 1. Cancellation rates rise as the price does. In order to prevent cancellations of reservations, hotels could work on their pricing strategies and try to lower the rates for specific hotels based on locations. They can also provide some discounts to the consumers.
#
# 2. As the ratio of the cancellation and not cancellation of the resort hotel is higher in the resort hotel than the city hotels. So the hotels should provide a reasonable discount on the room prices on weekends or on holidays.
#
# 3. In the month of January, hotels can start campaigns or marketing with a reasonable amount to increase their revenue as the cancellation is the highest in this month.
#
# 4. They can also increase the quality of their hotels and their services mainly in Portugal to reduce the cancellation rate.
